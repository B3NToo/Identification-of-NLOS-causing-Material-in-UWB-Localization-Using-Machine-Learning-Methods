# %%
import pandas as pd 
import numpy as np
import time
import os, sys
import numpy as np
from numpy import linalg
import pandas as pd
from scipy import stats
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from utility.visualizer import visualize_nlos

# %%
folders=  ["../../my_data/identification-dataset/nlos/anAn/metal/data1/",
            "../../my_data/identification-dataset/nlos/anAn/metal/data2/",
            "../../my_data/identification-dataset/nlos/anAn/metal/data3/",
            "../../my_data/identification-dataset/nlos/anAn/metal/data4/",
            "../../my_data/identification-dataset/nlos/anAn/metal/data5/",
            "../../my_data/identification-dataset/nlos/anAn/metal/data6/"]

fig_list = []
#for folders in folders:
#    fig_list.append(visualize_nlos(folders))
fig_list.append(visualize_nlos(folders[0]))
