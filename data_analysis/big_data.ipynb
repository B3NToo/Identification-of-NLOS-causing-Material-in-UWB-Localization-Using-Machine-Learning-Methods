# %%
import pandas as pd 
import numpy as np
import time
import os, sys
import numpy as np
from numpy import linalg
import pandas as pd
from scipy import stats
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from utility.visualizer import visualize_nlos

# %% [markdown]
# # Analysis of all Idetification Measurements

# %% [markdown]
# ## Conclusion
# In every measurement, the direct path of between the 'Tag' and 'Anchor 1' is blocked.

# %% [markdown]
# ## Metal Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/metal/data1/",
            "../../my_data/identification-dataset/nlos/anTag/metal/data2/",
            "../../my_data/identification-dataset/nlos/anTag/metal/data3/",
            "../../my_data/identification-dataset/nlos/anTag/metal/data4/",
            "../../my_data/identification-dataset/nlos/anTag/metal/data5/",
            "../../my_data/identification-dataset/nlos/anTag/metal/data6/"]

fig_list = []
for folders in folders:
    fig_list.append(visualize_nlos(folders))

# %% [markdown]
# ## Foam Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/foam/data1/",
            "../../my_data/identification-dataset/nlos/anTag/foam/data2/",
            "../../my_data/identification-dataset/nlos/anTag/foam/data3/",
            "../../my_data/identification-dataset/nlos/anTag/foam/data4/",
            "../../my_data/identification-dataset/nlos/anTag/foam/data5/",
            "../../my_data/identification-dataset/nlos/anTag/foam/data6/"]

for folders in folders:
    fig = visualize_nlos(folders)

# %% [markdown]
# ## Plastic Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/plastic/data1/",
            "../../my_data/identification-dataset/nlos/anTag/plastic/data2/",
            "../../my_data/identification-dataset/nlos/anTag/plastic/data3/",
            "../../my_data/identification-dataset/nlos/anTag/plastic/data4/",
            "../../my_data/identification-dataset/nlos/anTag/plastic/data5/",
            "../../my_data/identification-dataset/nlos/anTag/plastic/data6/"]

for folders in folders:
    fig = visualize_nlos(folders)

# %% [markdown]
# ## Cardboard Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/cardboard/data1/",
            "../../my_data/identification-dataset/nlos/anTag/cardboard/data2/",
            "../../my_data/identification-dataset/nlos/anTag/cardboard/data3/",
            "../../my_data/identification-dataset/nlos/anTag/cardboard/data4/",
            "../../my_data/identification-dataset/nlos/anTag/cardboard/data5/",
            "../../my_data/identification-dataset/nlos/anTag/cardboard/data6/"]

for folders in folders:
    fig = visualize_nlos(folders)

# %% [markdown]
# ## Wooden-Cabinet Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data1/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data2/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data3/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data4/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data5/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-cabinet/data6/"]

for folders in folders:
    fig = visualize_nlos(folders)

# %% [markdown]
# ## Wooden-Shelf Obstacle Measurement

# %%
folders=  ["../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data1/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data2/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data3/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data4/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data5/",
            "../../my_data/identification-dataset/nlos/anTag/wooden-shelf/data6/"]

for folders in folders:
    fig = visualize_nlos(folders)
